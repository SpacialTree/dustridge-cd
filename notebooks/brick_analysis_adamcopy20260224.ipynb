# %%
cd /orange/adamginsburg/jwst/cloudc/smart-plotters/
# Out:
# /blue/adamginsburg/savannahgramze/cloudc/smart-plotters

# %%
# %pip install -e .
# Out:
# DEPRECATION: Loading egg at /blue/adamginsburg/adamginsburg/miniconda3/envs/python312/lib/python3.12/site-packages/omnifit-0.1.dev214+g8128111.d20250320-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Obtaining file:///blue/adamginsburg/savannahgramze/cloudc/smart-plotters
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for smart_plotters (pyproject.toml) ... done
#   Created wheel for smart_plotters: filename=smart_plotters-0.0.1-0.editable-py3-none-any.whl size=3730 sha256=7f3aea6253a8b093d30409be04a9da2354a7d88797238ff87e95071e323fef4e
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from regions import Regions
import regions
from astropy.io import fits
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.modeling import models, fitting
from astropy.table import Table, vstack

from dust_extinction.averages import CT06_MWGC

from smart_plotters.jwst_plots import JWSTCatalog, make_cat_use, make_brick_cat
from smart_plotters.cutout_plot import get_cutout_405, get_cutout_jwst_ice
import smart_plotters.co_ice as co_map 
from smart_plotters import cmd_plot 

# /home/savannahgramze/orange_link/adamginsburg/jwst/cloudc/dustridge-cd/notebooks/brick_analysis.ipynb
# Out:
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]

# %%
print('HELLO')
# Out:
# HELLO

# %%
cat_brick = make_brick_cat()
cat_brick.catalog['Av'] = cat_brick.get_Av('f182m', 'f212n')
cat_brick.catalog['N(CO)'] = co_map.get_co_ice_column(cat_brick, cat_brick.catalog['Av'], ext=CT06_MWGC(), ref_band='f405n')
# Out:
# Reading /orange/adamginsburg/jwst/brick/catalogs/basic_merged_indivexp_photometry_tables_merged_qualcuts_oksep2221.fits

# %%
def get_rc_sel_mask(cat):
    x = np.linspace(0, 2.5, 10)
    
    x0 = 0.52
    mask_x0_left = cat.color('f182m', 'f212n') > x0

    y0 = 14.8
    mask_above_y0 = cat.band('f182m') > y0
    mask_rc = mask_above_y0 & mask_x0_left

    pt1 = (0.5, 14.3)
    pt2 = (2.0, 20.)
    y1 = (pt2[1] - pt1[1]) / (pt2[0] - pt1[0]) * (x - pt1[0]) + pt1[1]
    mask_below_y1 = cat.band('f182m') > ( (pt2[1] - pt1[1]) / (pt2[0] - pt1[0]) * (cat.color('f182m', 'f212n') - pt1[0]) + pt1[1] )
    mask_rc = mask_below_y1 & mask_rc

    pt1 = (0.5, 15.5)
    pt2 = (2.0, 20.9)
    y2 = (pt2[1] - pt1[1]) / (pt2[0] - pt1[0]) * (x - pt1[0]) + pt1[1]
    mask_above_y2 = cat.band('f182m') < ( (pt2[1] - pt1[1]) / (pt2[0] - pt1[0]) * (cat.color('f182m', 'f212n') - pt1[0]) + pt1[1] )
    mask_rc = mask_rc & mask_above_y2

    return mask_rc

# %%
cat_brick_rc = JWSTCatalog(cat_brick.catalog[get_rc_sel_mask(cat_brick)])

# %%
cat_brick.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', s=1, alpha=0.5, color='gray', label='All Sources')
cat_brick_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', s=1, alpha=0.5, color='red', label='Red Clump')
plt.xlim(0, 3)
plt.ylim(-3, 0.5)
plt.legend()

# %%
cat_brick.plot_CMD('f182m', 'f212n', 'f182m', s=1, alpha=0.5, color='gray')
cat_brick_rc.plot_CMD('f182m', 'f212n', 'f182m', s=1, alpha=0.5, color='red')
plt.gca().invert_yaxis()
plt.xlim(0, 3)
plt.ylim(22, 14.5)
plt.title('Red Clump Selection Brick')
# Out:
# Text(0.5, 1.0, 'Red Clump Selection Brick')

# %%
reg_brick_north = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_north.reg')
reg_brick_south = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_south.reg')
reg_brick_head = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_head.reg')
reg_brick_sfluff = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_sfluff.reg')
reg_brick_nfluff = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_nfluff.reg')
reg_brick_sfr = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_sfr_tightest.reg')
reg_brick_sfrwide = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_sfr.reg')
reg_brick_punch = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_punch.reg')
reg_brick_sfore = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_sfore.reg')
reg_brick_nclear = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_nclear.reg')
#reg_brick_topL = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_topL.reg')
reg_brick_topc = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_topc.reg')
#reg_brick_fil = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_fil.reg')
reg_brick_middle = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_middle.reg')

reg_brick_A = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_A.reg')
reg_brick_B = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_B.reg')
reg_brick_C = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_C.reg')
reg_brick_D = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_D.reg')

reg_brick_claw1 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/claw1.reg')
reg_brick_claw2 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/claw2.reg')
reg_brick_claw3 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/claw3.reg')

# %%
fn_brick = '/orange/adamginsburg/jwst/brick/F405N/pipeline/jw02221-o001_t001_nircam_clear-f405n-merged_i2d.fits'
hdu_brick = fits.open(fn_brick)
ww_brick = WCS(hdu_brick['SCI'].header)
nanfield_brick = np.nan * hdu_brick['SCI'].data

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)
cat_brick_rc.plot_position(ax=ax, transform=ax.get_transform('world'), s=1, cmap='Greys', c=cat_brick_rc.color('f182m', 'f212n'))

reg_brick_north[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='red')
reg_brick_south[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='blue')
reg_brick_head[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='green')
reg_brick_sfluff[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='cyan')
reg_brick_nfluff[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='magenta')
reg_brick_sfr[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='purple')
reg_brick_punch[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='orange')
reg_brick_sfore[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='pink')
reg_brick_nclear[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='k')
#reg_brick_topL[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='brown')
reg_brick_topc[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='gray')
#reg_brick_fil[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='lime')
reg_brick_sfrwide[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='brown')

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)
cat_brick_rc.plot_position(ax=ax, transform=ax.get_transform('world'), s=1, cmap='Greys', c=cat_brick_rc.color('f182m', 'f212n'))

reg_brick_A[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='red')
reg_brick_B[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='blue')
reg_brick_C[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='green')
reg_brick_D[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='goldenrod')

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)
cat_brick_rc.plot_position(ax=ax, transform=ax.get_transform('world'), s=1, cmap='Greys', c=cat_brick_rc.color('f182m', 'f212n'))

reg_brick_claw1[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='red')
reg_brick_claw2[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='blue')
reg_brick_claw3[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='green')

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
cat_brick_north = JWSTCatalog(cat_brick.table_region_mask(reg_brick_north, ww_brick)) #  
cat_brick_south = JWSTCatalog(cat_brick.table_region_mask(reg_brick_south, ww_brick))
cat_brick_head = JWSTCatalog(cat_brick.table_region_mask(reg_brick_head, ww_brick))
cat_brick_sfluff = JWSTCatalog(cat_brick.table_region_mask(reg_brick_sfluff, ww_brick))
cat_brick_nfluff = JWSTCatalog(cat_brick.table_region_mask(reg_brick_nfluff, ww_brick))
cat_brick_sfr = JWSTCatalog(cat_brick.table_region_mask(reg_brick_sfr, ww_brick))
cat_brick_punch = JWSTCatalog(cat_brick.table_region_mask(reg_brick_punch, ww_brick))
cat_brick_sfore = JWSTCatalog(cat_brick.table_region_mask(reg_brick_sfore, ww_brick))
cat_brick_nclear = JWSTCatalog(cat_brick.table_region_mask(reg_brick_nclear, ww_brick))
#cat_brick_topL = JWSTCatalog(cat_brick.table_region_mask(reg_brick_topL, ww_brick))
cat_brick_topc = JWSTCatalog(cat_brick.table_region_mask(reg_brick_topc, ww_brick))
#cat_brick_fil = JWSTCatalog(cat_brick.table_region_mask(reg_brick_fil, ww_brick))
cat_brick_sfrwide = JWSTCatalog(cat_brick.table_region_mask(reg_brick_sfrwide, ww_brick))
cat_brick_middle = JWSTCatalog(cat_brick.table_region_mask(reg_brick_middle, ww_brick))

cat_brick_A = JWSTCatalog(cat_brick.table_region_mask(reg_brick_A, ww_brick))
cat_brick_B = JWSTCatalog(cat_brick.table_region_mask(reg_brick_B, ww_brick))
cat_brick_C = JWSTCatalog(cat_brick.table_region_mask(reg_brick_C, ww_brick))
cat_brick_D = JWSTCatalog(cat_brick.table_region_mask(reg_brick_D, ww_brick))

cat_brick_claw1 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_claw1, ww_brick))
cat_brick_claw2 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_claw2, ww_brick))
cat_brick_claw3 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_claw3, ww_brick))

# %%
cat_brick_north_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_north, ww_brick)) #  
cat_brick_south_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_south, ww_brick))
cat_brick_head_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_head, ww_brick))
cat_brick_sfluff_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_sfluff, ww_brick))
cat_brick_nfluff_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_nfluff, ww_brick))
cat_brick_sfr_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_sfr, ww_brick))
cat_brick_punch_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_punch, ww_brick))
cat_brick_sfore_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_sfore, ww_brick))
cat_brick_nclear_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_nclear, ww_brick))
#cat_brick_topL_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_topL, ww_brick))
cat_brick_topc_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_topc, ww_brick))
#cat_brick_fil_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_fil, ww_brick))
cat_brick_sfrwide_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_sfrwide, ww_brick))
cat_brick_middle_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_middle, ww_brick))

cat_brick_A_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_A, ww_brick))
cat_brick_B_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_B, ww_brick))
cat_brick_C_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_C, ww_brick))
cat_brick_D_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_D, ww_brick))

# %% [markdown]
# # Red Clump

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_north_rc.plot_position(ax=ax, color='red', s=1, label='North', transform=ax.get_transform('world'))
cat_brick_south_rc.plot_position(ax=ax, color='blue', s=1, label='South', transform=ax.get_transform('world'))
cat_brick_head_rc.plot_position(ax=ax, color='green', s=1, label='Head', transform=ax.get_transform('world'))
cat_brick_sfluff_rc.plot_position(ax=ax, color='cyan', s=1, label='South Fluff', transform=ax.get_transform('world'))
cat_brick_nfluff_rc.plot_position(ax=ax, color='magenta', s=1, label='North Fluff', transform=ax.get_transform('world'))
cat_brick_punch_rc.plot_position(ax=ax, color='orange', s=1, label='Punch', transform=ax.get_transform('world'))
cat_brick_sfore_rc.plot_position(ax=ax, color='pink', s=1, label='South Foreground', transform=ax.get_transform('world'))
cat_brick_nclear_rc.plot_position(ax=ax, color='k', s=1, label='North Clear', transform=ax.get_transform('world'))
cat_brick_sfrwide_rc.plot_position(ax=ax, color='brown', s=1, label='Star Forming Region Wide', transform=ax.get_transform('world'))
cat_brick_sfr_rc.plot_position(ax=ax, color='purple', s=1, label='Star Forming Region', transform=ax.get_transform('world'))
cat_brick_topc_rc.plot_position(ax=ax, color='gray', s=1, label='Top Center', transform=ax.get_transform('world'))

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_A_rc.plot_position(ax=ax, color='red', s=5, label='A', transform=ax.get_transform('world'), marker='o')
cat_brick_B_rc.plot_position(ax=ax, color='blue', s=5, label='B', transform=ax.get_transform('world'), marker='>')
cat_brick_C_rc.plot_position(ax=ax, color='green', s=1, label='C', transform=ax.get_transform('world'), marker='s')
cat_brick_D_rc.plot_position(ax=ax, color='goldenrod', s=1, label='D', transform=ax.get_transform('world'), marker='^')

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
fig = plt.figure(figsize=(12,8))
ax1 = plt.subplot(445)
ax2 = plt.subplot(446)
ax3 = plt.subplot(447)
ax4 = plt.subplot(448)
ax5 = plt.subplot(449)
ax6 = plt.subplot(4, 4, 10)
ax7 = plt.subplot(4, 4, 11)
ax8 = plt.subplot(4, 4, 12)
ax9 = plt.subplot(4, 4, 13)
ax10 = plt.subplot(4, 4, 14)
ax11 = plt.subplot(4, 4, 15)

cat_brick_north_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='North', ax=ax1)

cat_brick_south_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='South', ax=ax2)

cat_brick_head_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Head', ax=ax3)

cat_brick_sfluff_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='South Fluff', ax=ax4)

cat_brick_nfluff_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='magenta', s=1, label='North Fluff', ax=ax5)

cat_brick_punch_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Punch', ax=ax6)

cat_brick_sfore_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='pink', s=1, label='South Foreground', ax=ax7)

cat_brick_nclear_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='k', s=1, label='North Clear', ax=ax8)

cat_brick_sfr_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='purple', s=1, label='Star Forming Region', ax=ax9)

cat_brick_sfrwide_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='brown', s=1, label='Star Forming Region Wide', ax=ax10)

cat_brick_topc_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='gray', s=1, label='Top Center', ax=ax11)

axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11]
for a in axes:
    a.set_xlabel('F182M - F212N', fontsize=12)
    a.set_ylabel('F405N - F466N', fontsize=12)
    a.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    a.legend()
    a.set_xlim(0.5, 2.7)
    a.set_ylim(-2.3, 0.1)

plt.tight_layout()

ax = ax1.inset_axes([1, 1.4, 3, 1.5], projection=ww_brick)
plt.imshow(nanfield_brick)
cat_brick_rc.plot_position(ax=ax, transform=ax.get_transform('world'), s=1, cmap='Greys', c=cat_brick_rc.color('f182m', 'f212n'))
ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

reg_brick_north[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='red')
reg_brick_south[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='blue')
reg_brick_head[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='green')
reg_brick_sfluff[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='cyan')
reg_brick_nfluff[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='magenta')
reg_brick_sfr[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='purple')
reg_brick_punch[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='orange')
reg_brick_sfore[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='pink')
reg_brick_nclear[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='k')
reg_brick_topc[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='gray')
reg_brick_sfrwide[0].to_pixel(ww_brick).plot(ax=ax, facecolor='none', edgecolor='brown')

#plt.savefig('/orange/adamginsburg/jwst/cloudc/figures/brick_rc_CCDs.png', dpi=300, bbox_inches='tight')
#plt.savefig('/orange/adamginsburg/jwst/cloudc/figures/brick_rc_CCDs.pdf', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(12, 10))

ax1 = plt.subplot(341)
cat_brick_north_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='North', ax=ax1)

ax2 = plt.subplot(342)
cat_brick_south_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='South', ax=ax2)

ax3 = plt.subplot(343)
cat_brick_head_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Head', ax=ax3)

ax4 = plt.subplot(344)
cat_brick_sfluff_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='South Fluff', ax=ax4)

ax5 = plt.subplot(345)
cat_brick_nfluff_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='magenta', s=1, label='North Fluff', ax=ax5)

ax6 = plt.subplot(346)
cat_brick_punch_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Punch', ax=ax6)

ax7 = plt.subplot(347)
cat_brick_sfore_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='pink', s=1, label='South Foreground', ax=ax7)

ax8 = plt.subplot(348)
cat_brick_nclear_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='k', s=1, label='North Clear', ax=ax8)

ax9 = plt.subplot(349)
cat_brick_sfr_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='purple', s=1, label='Star Forming Region', ax=ax9)

ax10 = plt.subplot(3,4,10)
cat_brick_sfrwide_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='brown', s=1, label='Star Forming Region Wide', ax=ax10)

ax11 = plt.subplot(3,4,11)
cat_brick_topc_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='gray', s=1, label='Top Center', ax=ax11)

axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11]
for ax in axes:
    plt.sca(ax)
    plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    ax.set_xlim(0.5, 2.7)
    ax.set_ylim(-2.3, 0.1)
    plt.legend()

plt.tight_layout()

# %%
ax1 = plt.subplot(221)
cat_brick_A_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=5, label='A', marker='o', ax=ax1)

ax2 = plt.subplot(222)
cat_brick_B_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=5, label='B', marker='>', ax=ax2)

ax3 = plt.subplot(223)
cat_brick_C_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='C', marker='s', ax=ax3)

ax4 = plt.subplot(224)
cat_brick_D_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='goldenrod', s=1, label='D', marker='^', ax=ax4)

axes = [ax1, ax2, ax3, ax4]
for ax in axes:
    plt.sca(ax)
    plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    ax.set_xlim(0.5, 2.7)
    ax.set_ylim(-2.3, 0.1)
    ax.axvline(0.65, color='k', linestyle='--')
    plt.legend()

plt.tight_layout()

# %%
ax1 = plt.subplot(221)
cat_brick_A_rc.plot_CCD('f182m', 'f212n', 'f356w', 'f444w', color='red', s=5, label='A', marker='o', ax=ax1)

ax2 = plt.subplot(222)
cat_brick_B_rc.plot_CCD('f182m', 'f212n', 'f356w', 'f444w', color='blue', s=5, label='B', marker='>', ax=ax2)

ax3 = plt.subplot(223)
cat_brick_C_rc.plot_CCD('f182m', 'f212n', 'f356w', 'f444w', color='green', s=3, label='C', marker='s', ax=ax3)

ax4 = plt.subplot(224)
cat_brick_D_rc.plot_CCD('f182m', 'f212n', 'f356w', 'f444w', color='goldenrod', s=5, label='D', marker='^', ax=ax4)

axes = [ax1, ax2, ax3, ax4]
for ax in axes:
    plt.sca(ax)
    plt.plot([0.6, 2.5], [0.2, 2.2], color='k', linestyle='dashed', alpha=0.25)
    ax.set_xlim(0.5, 2.7)
    #ax.set_ylim(-2.3, 0.1)
    ax.axvline(0.65, color='k', linestyle='--')
    plt.legend()

plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
ax1 = plt.subplot(231)
cat_brick_A_rc.plot_CCD('f200w', 'f444w', 'f356w', 'f444w', color='red', s=5, label='A', marker='o', ax=ax1)

ax2 = plt.subplot(232)
cat_brick_B_rc.plot_CCD('f200w', 'f444w', 'f356w', 'f444w', color='blue', s=5, label='B', marker='>', ax=ax2)

ax3 = plt.subplot(233)
cat_brick_C_rc.plot_CCD('f200w', 'f444w', 'f356w', 'f444w', color='green', s=3, label='C', marker='s', ax=ax3)

ax4 = plt.subplot(234)
cat_brick_D_rc.plot_CCD('f200w', 'f444w', 'f356w', 'f444w', color='goldenrod', s=5, label='D', marker='^', ax=ax4)

ax5 = plt.subplot(235)
cat_brick_north_rc.plot_CCD('f200w', 'f444w', 'f356w', 'f444w', color='teal', s=5, label='north', marker='*', ax=ax5)

ax6 = plt.subplot(236)
cat_brick_south_rc.plot_CCD('f200w', 'f444w', 'f356w', 'f444w', color='purple', s=5, label='south', marker='p', ax=ax6)


axes = [ax1, ax2, ax3, ax4, ax5, ax6]
for ax in axes:
    plt.sca(ax)
    plt.plot([1.4, 4], [0.2, 2.2], color='k', linestyle='dashed', alpha=0.25)
    plt.plot([2, 4.6], [0.2, 2.2], color='k', linestyle=':', alpha=0.25)
    ax.set_xlim(1, 4.5)
    ax.set_ylim(-0.1, 2.3)
    #ax.axvline(0.65, color='k', linestyle='--')
    plt.legend(loc='upper left')

plt.tight_layout()

# %%
ax1 = plt.subplot(111, projection=ww_brick)
ax1.imshow(nanfield_brick)
y1,y2 = 0.2, 1.2
x1,x2 = 2.0, 4.6
m = (y2-y1)/(x2-x1)
b = y1 - m * x1
adams_mask = cat_brick_rc.color('f356w', 'f444w') < (cat_brick_rc.color('f200w', 'f444w') * m + b)
cat_brick_rc_356ish = JWSTCatalog(cat_brick_rc.catalog[adams_mask])
cat_brick_rc_356ish.plot_position(ax=ax1, transform=ax.get_transform('world'), s=1, cmap='Greys', c=cat_brick_rc_356ish.color('f200w', 'f356w'))
ax1.set_xlabel('Declination')
ax1.set_ylabel('Right Ascension')

# %%
y1,y2 = 0.2, 1.2
x1,x2 = 2.0, 4.6
m = (y2-y1)/(x2-x1)
b = 0.2 - m * x1
m,b
# Out:
# (0.3846153846153847, -0.5692307692307694)

# %%
print("HELLOOOOOOOOO")
# Out:
# HELLOOOOOOOOO

# %%
cat_brick_middle.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='brown', s=1, label='Middle', alpha=0.1)#, ax=ax12)
#cat_brick_middle_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='brown', s=5, label='Middle')#, ax=ax12)
# Out:
# <Axes: xlabel='[F182M] - [F212N]', ylabel='[F405N] - [F466N]'>

# %%
catalog_list = [cat_brick_north_rc, cat_brick_south_rc, cat_brick_head_rc, cat_brick_sfluff_rc, cat_brick_nfluff_rc, cat_brick_punch_rc, cat_brick_sfore_rc, cat_brick_nclear_rc, cat_brick_sfr_rc, cat_brick_sfrwide_rc, cat_brick_topc_rc]
name_list = ['North', 'South', 'Head', 'South Fluff', 'North Fluff', 'Punch', 'South Foreground', 'North Clear', 'Star Forming Region', 'Star Forming Region Wide', 'Top Center']
color_list = ['r', 'b', 'g', 'cyan', 'magenta', 'orange', 'pink', 'k', 'purple', 'brown', 'gray']
cutoffs = [0.8, 0.9, 0.75, 0.9, 0.7, 0.75, 1, 0.8, 1, 1, 0.7]
rang = np.linspace(0.5, 2.7, 100)

fig = plt.figure(figsize=(12,10))
ax1 = plt.subplot(341)
ax2 = plt.subplot(342)
ax3 = plt.subplot(343)
ax4 = plt.subplot(344)
ax5 = plt.subplot(345)
ax6 = plt.subplot(346)
ax7 = plt.subplot(347)
ax8 = plt.subplot(348)
ax9 = plt.subplot(349)
ax10 = plt.subplot(3,4,10)
ax11 = plt.subplot(3,4,11)
axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11]

for i in range(len(catalog_list)):
    ax = axes[i]
    cat = catalog_list[i]
    cat = JWSTCatalog(cat.catalog[cat.color('f182m', 'f212n') > cutoffs[i]])
    cat.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', ax=ax, s=1, alpha=0.5, label=name_list[i], color=color_list[i])
    #ax.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    x = cat.color('f182m', 'f212n')
    y = cat.color('f405n', 'f466n')
    slopes = []
    intercepts = []

    for j in range(1000):
        indices = np.random.choice(len(x), len(x), replace=True)
        x_boot = x[indices]
        y_boot = y[indices]
        
        fit = fitting.LinearLSQFitter()
        line_boot = fit(models.Linear1D(), x_boot, y_boot)
        slopes.append(line_boot.slope.value)
        intercepts.append(line_boot.intercept.value)
        ax.plot(rang, line_boot(rang), color='gray', alpha=0.01)

    ax.plot(rang, np.mean(slopes) * rang + np.mean(intercepts), color='r', label=f'y = ({np.mean(slopes):.2f}$\pm${np.std(slopes):.2f})x + ({np.median(intercepts):.2f}$\pm${np.std(intercepts):.2f})', linewidth=2, linestyle='--')
    ax.set_xlim(0.5, 2.7)
    ax.set_ylim(-2.3, 0.5)
    ax.legend(loc='upper right')
    #ax.axvline(0.8)

plt.tight_layout()
# Out:
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# /scratch/local/25585083/ipykernel_1169737/2460574550.py:43: SyntaxWarning: invalid escape sequence '\p'
#   ax.plot(rang, np.mean(slopes) * rang + np.mean(intercepts), color='r', label=f'y = ({np.mean(slopes):.2f}$\pm${np.std(slopes):.2f})x + ({np.median(intercepts):.2f}$\pm${np.std(intercepts):.2f})', linewidth=2, linestyle='--')
# /scratch/local/25585083/ipykernel_1169737/2460574550.py:43: SyntaxWarning: invalid escape sequence '\p'
#   ax.plot(rang, np.mean(slopes) * rang + np.mean(intercepts), color='r', label=f'y = ({np.mean(slopes):.2f}$\pm${np.std(slopes):.2f})x + ({np.median(intercepts):.2f}$\pm${np.std(intercepts):.2f})', linewidth=2, linestyle='--')

# %%
catalog_list = [cat_brick_north_rc, cat_brick_south_rc, cat_brick_head_rc, cat_brick_sfluff_rc, cat_brick_nfluff_rc, cat_brick_punch_rc, cat_brick_sfore_rc, cat_brick_nclear_rc, cat_brick_sfr_rc, cat_brick_sfrwide_rc, cat_brick_topc_rc]
name_list = ['North', 'South', 'Head', 'South Fluff', 'North Fluff', 'Punch', 'South Foreground', 'North Clear', 'Star Forming Region', 'Star Forming Region Wide', 'Top Center']
color_list = ['r', 'b', 'g', 'cyan', 'magenta', 'orange', 'pink', 'k', 'purple', 'brown', 'gray']
cutoffs = [0.8, 0.9, 0.75, 0.9, 0.7, 0.75, 1, 0.8, 1, 1, 0.7]
rang = np.linspace(0.5, 2.7, 100)

ax = plt.subplot(111)

for i in range(len(catalog_list)):
    #ax = axes[i]
    cat = catalog_list[i]
    cat = JWSTCatalog(cat.catalog[cat.color('f182m', 'f212n') > cutoffs[i]])
    #cat.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', ax=ax, s=1, alpha=0.5, label=name_list[i], color=color_list[i])
    #ax.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    x = cat.color('f182m', 'f212n')
    y = cat.color('f405n', 'f466n')
    slopes = []
    intercepts = []

    for j in range(1000):
        indices = np.random.choice(len(x), len(x), replace=True)
        x_boot = x[indices]
        y_boot = y[indices]
        
        fit = fitting.LinearLSQFitter()
        line_boot = fit(models.Linear1D(), x_boot, y_boot)
        slopes.append(line_boot.slope.value)
        intercepts.append(line_boot.intercept.value)
        #ax.plot(rang, line_boot(rang), color='gray', alpha=0.01)

    ax.errorbar(np.mean(slopes), np.median(intercepts), xerr=np.std(slopes), yerr=np.std(intercepts), fmt='o', color=color_list[i], alpha=0.7)
    ax.scatter(np.mean(slopes), np.median(intercepts), label=name_list[i], color=color_list[i])

ax.set_xlabel('Slope')
ax.set_ylabel('Intercept')
plt.legend(loc='lower left')

plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 10))

ax1 = plt.subplot(341)
ax2 = plt.subplot(342)
ax3 = plt.subplot(343)
ax4 = plt.subplot(344)
ax5 = plt.subplot(345)
ax6 = plt.subplot(346)
ax7 = plt.subplot(347)
ax8 = plt.subplot(348)
ax9 = plt.subplot(349)
ax10 = plt.subplot(3,4,10)
ax11 = plt.subplot(3,4,11)
axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11]#, ax12]

ax1.hexbin(cat_brick_north_rc.catalog['Av'], cat_brick_north_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax1.set_title('Brick North')
ax2.hexbin(cat_brick_south_rc.catalog['Av'], cat_brick_south_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax2.set_title('Brick South')
ax3.hexbin(cat_brick_head_rc.catalog['Av'], cat_brick_head_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax3.set_title('Brick Head')
ax4.hexbin(cat_brick_sfluff_rc.catalog['Av'], cat_brick_sfluff_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax4.set_title('Brick South Fluff')
ax5.hexbin(cat_brick_nfluff_rc.catalog['Av'], cat_brick_nfluff_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax5.set_title('Brick North Fluff')
ax6.hexbin(cat_brick_punch_rc.catalog['Av'], cat_brick_punch_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax6.set_title('Brick Punch')
ax7.hexbin(cat_brick_sfore_rc.catalog['Av'], cat_brick_sfore_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax7.set_title('Brick South Foreground')
ax8.hexbin(cat_brick_nclear_rc.catalog['Av'], cat_brick_nclear_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax8.set_title('Brick North Clear')
ax9.hexbin(cat_brick_sfr_rc.catalog['Av'], cat_brick_sfr_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax9.set_title('Brick Star Forming Region')
ax10.hexbin(cat_brick_sfrwide_rc.catalog['Av'], cat_brick_sfrwide_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax10.set_title('Brick Star Forming Region Wide')
ax11.hexbin(cat_brick_topc_rc.catalog['Av'], cat_brick_topc_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax11.set_title('Brick Top Center')

Av_offset = 17
NCOofAV_alt1 = 1.1e21 * np.linspace(0.1, 100, 1000) * 5e-4
NCOofAV_alt3 = 1.1e21 * np.linspace(0.1, 100, 1000) * 1.6e-4
l1, = ax1.plot(np.linspace(0.1, 100, 1000)+Av_offset, NCOofAV_alt3, linewidth=2, 
        label='100% of CO in ice if \nN(H$_2$)=1.1$\\times10^{21}$ A$_V$ \nand CO/H$_2$=1.6x10$^{-4}$', color='r', linestyle='-')
l3, = ax1.plot(np.linspace(0.1, 100, 1000)+Av_offset, NCOofAV_alt1, linewidth=2, 
        label='CO/H$_2$=5x10$^{-4}$', color='r', linestyle='--')
ax1.set_xlim(10, 80)
ax1.set_ylim(5e16, 5e19)
ax1.legend()

for ax in axes:
    ax.plot(np.linspace(0.1, 100, 1000)+Av_offset, NCOofAV_alt3, linewidth=2, color='r', linestyle='-')
    ax.plot(np.linspace(0.1, 100, 1000)+Av_offset, NCOofAV_alt1, linewidth=2, color='r', linestyle='--')
    ax.set_xlabel('A$_V$ (mag)', fontsize=12)
    ax.set_ylabel('N(CO Ice) [cm$^{-2}$]', fontsize=12)
    ax.set_xlim(10, 80)
    ax.set_ylim(2e17, 5e19)
    ax.set_yscale('log')

plt.tight_layout()

plt.savefig('/orange/adamginsburg/jwst/cloudc/figures/brick_rc_COice_vs_Av.png', dpi=300, bbox_inches='tight')
plt.savefig('/orange/adamginsburg/jwst/cloudc/figures/brick_rc_COice_vs_Av.pdf', bbox_inches='tight')

# %%
fig, axes = plt.subplots(4, 3, figsize=(12,10))

for i in range(len(catalog_list)):
    ax = axes.flatten()[i]
    cat = catalog_list[i]
    ax.hexbin(cat.catalog['Av'], cat.catalog['N(CO)']/cat.catalog['Av'], yscale='log', extent=(10, 80, np.log10(1e15), np.log10(1e18)), cmap='viridis', gridsize=50, mincnt=1)
    ax.set_title(name_list[i])
    ax.plot(np.linspace(0.1, 100, 1000)+Av_offset, NCOofAV_alt3/(np.linspace(0.1, 100, 1000)+Av_offset), linewidth=2, color='r', linestyle='-')
    ax.plot(np.linspace(0.1, 100, 1000)+Av_offset, NCOofAV_alt1/(np.linspace(0.1, 100, 1000)+Av_offset), linewidth=2, color='r', linestyle='--')
    
    ax.set_xlabel('A$_V$ (mag)', fontsize=12)
    ax.set_ylabel('N(CO Ice)/Av [cm$^{-2}$ mag$^{-1}$]', fontsize=12)
    ax.set_yscale('log')
    ax.set_xlim(10, 80)
    ax.set_ylim(1e15, 1e18)
    #ax.legend()

plt.tight_layout()

# %%
Av_bins = np.arange(10, 81, 10)
# average N(CO) in each bin of Av for each region
mean_NCO_per_bin = []
for i in range(len(catalog_list)):
    cat = catalog_list[i]
    mean_NCO = []
    for j in range(len(Av_bins)-1):
        bin_mask = (cat.catalog['Av'] >= Av_bins[j]) & (cat.catalog['Av'] < Av_bins[j+1])
        mean_NCO.append(np.nanmean(cat.catalog['N(CO)'][bin_mask]))
    mean_NCO_per_bin.append(mean_NCO)

for i in range(len(mean_NCO_per_bin)):
    plt.plot(Av_bins[:-1]+5, mean_NCO_per_bin[i], label=name_list[i], color=color_list[i])
plt.xlabel('A$_V$ (mag)', fontsize=12)
plt.ylabel('Mean N(CO Ice) [cm$^{-2}$]', fontsize=12)
plt.yscale('log')
plt.legend()
plt.tight_layout()
# Out:
# /scratch/local/25585083/ipykernel_1169737/2874737665.py:9: RuntimeWarning: Mean of empty slice
#   mean_NCO.append(np.nanmean(cat.catalog['N(CO)'][bin_mask]))

# %%
Av_bins = np.arange(10, 81, 10)
# average N(CO) in each bin of Av for each region

fig, axes = plt.subplots(4, 3, figsize=(12,10))

for i in range(len(catalog_list)):
    ax = axes.flatten()[i]
    cat = catalog_list[i]
    mean_NCO = []
    std_NCO = []
    for j in range(len(Av_bins)-1):
        bin_mask = (cat.catalog['Av'] >= Av_bins[j]) & (cat.catalog['Av'] < Av_bins[j+1])
        mean_NCO.append(np.nanmean(cat.catalog['N(CO)'][bin_mask]))
        std_NCO.append(np.nanstd(cat.catalog['N(CO)'][bin_mask]))
    mean_NCO = np.array(mean_NCO)
    std_NCO = np.array(std_NCO)

    ax.errorbar(Av_bins[:-1]+5, mean_NCO, yerr=std_NCO, fmt='o', color=color_list[i])
    ax.plot(Av_bins[:-1]+5, mean_NCO, label=name_list[i], color=color_list[i])
    ax.set_xlabel('A$_V$ (mag)', fontsize=12)
    ax.set_ylabel('Mean N(CO Ice) [cm$^{-2}$]', fontsize=12)
    ax.set_yscale('log')
    ax.legend()

plt.tight_layout()
# Out:
# /scratch/local/25585083/ipykernel_1169737/2003077474.py:13: RuntimeWarning: Mean of empty slice
#   mean_NCO.append(np.nanmean(cat.catalog['N(CO)'][bin_mask]))
# /orange/adamginsburg/miniconda3/envs/python312/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
ax1 = plt.subplot(121)

ax1.hexbin(cat_brick_punch_rc.catalog['Av'], cat_brick_punch_rc.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax1.set_title('Brick Punch')

Av_offset = 17
NCOofAV_alt1 = 1.1e21 * np.linspace(0.1, 100, 1000) * 5e-4
NCOofAV_alt3 = 1.1e21 * np.linspace(0.1, 100, 1000) * 1.6e-4
l1, = ax1.plot(np.linspace(0.1, 100, 1000)+Av_offset, NCOofAV_alt3, linewidth=2, 
        label='100% of CO in ice if \nN(H$_2$)=1.1$\\times10^{21}$ A$_V$ \nand CO/H$_2$=1.6x10$^{-4}$', color='r', linestyle='-')
l3, = ax1.plot(np.linspace(0.1, 100, 1000)+Av_offset, NCOofAV_alt1, linewidth=2, 
        label='CO/H$_2$=5x10$^{-4}$', color='r', linestyle='--')
ax1.set_xlim(10, 80)
ax1.set_ylim(5e16, 5e19)
ax1.legend()

ax2 = plt.subplot(122)
cat_brick_punch_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Punch', ax=ax2)

plt.tight_layout()

# %%
ax1 = plt.subplot(121)

ax1.hexbin(cat_brick_punch.catalog['Av'], cat_brick_punch.catalog['N(CO)'], yscale='log', extent=(10, 80, np.log10(2e17), np.log10(5e19)), cmap='viridis', gridsize=50, mincnt=1)
ax1.set_title('Brick Punch')

Av_offset = 17
NCOofAV_alt1 = 1.1e21 * np.linspace(0.1, 100, 1000) * 5e-4
NCOofAV_alt3 = 1.1e21 * np.linspace(0.1, 100, 1000) * 1.6e-4
l1, = ax1.plot(np.linspace(0.1, 100, 1000)+Av_offset, NCOofAV_alt3, linewidth=2, 
        label='100% of CO in ice if \nN(H$_2$)=1.1$\\times10^{21}$ A$_V$ \nand CO/H$_2$=1.6x10$^{-4}$', color='r', linestyle='-')
l3, = ax1.plot(np.linspace(0.1, 100, 1000)+Av_offset, NCOofAV_alt1, linewidth=2, 
        label='CO/H$_2$=5x10$^{-4}$', color='r', linestyle='--')
ax1.set_xlim(10, 80)
ax1.set_ylim(5e16, 5e19)
ax1.legend()

ax2 = plt.subplot(122)
cat_brick_punch.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Punch', ax=ax2)

plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 10))

ax1 = plt.subplot(341)
cat_brick_north_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='North', ax=ax1)

ax2 = plt.subplot(342)
cat_brick_south_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='South', ax=ax2)

ax3 = plt.subplot(343)
cat_brick_head_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Head', ax=ax3)

ax4 = plt.subplot(344)
cat_brick_sfluff_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='South Fluff', ax=ax4)

ax5 = plt.subplot(345)
cat_brick_nfluff_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='magenta', s=1, label='North Fluff', ax=ax5)

ax6 = plt.subplot(346)
cat_brick_punch_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Punch', ax=ax6)

ax7 = plt.subplot(347)
cat_brick_sfore_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='pink', s=1, label='South Foreground', ax=ax7)

ax8 = plt.subplot(348)
cat_brick_nclear_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='k', s=1, label='North Clear', ax=ax8)

ax9 = plt.subplot(349)
cat_brick_sfr_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='purple', s=1, label='Star Forming Region', ax=ax9)

ax10 = plt.subplot(3,4,10)
cat_brick_sfrwide_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='brown', s=1, label='Star Forming Region Wide', ax=ax10)

#ax11 = plt.subplot(3,4,11)
#cat_brick_topL_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='brown', s=1, label='Top Left', ax=ax11)

ax11 = plt.subplot(3,4,11)
cat_brick_topc_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='gray', s=1, label='Top Center', ax=ax11)

axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11]#, ax12]
for ax in axes:
    plt.sca(ax)
    plt.plot([0.5, 1.], [-0, -0.5], color='k', linestyle='dashed')
    ax.set_xlim(0.5, 1)
    ax.set_ylim(-1, 0.1)
    plt.legend()

plt.tight_layout()

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_north_rc.plot_position(ax=ax, color='red', s=1, label='North', transform=ax.get_transform('world'))
cat_brick_south_rc.plot_position(ax=ax, color='blue', s=1, label='South', transform=ax.get_transform('world'))

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
ax1 = plt.subplot(211)
cat_brick_north_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='North', ax=ax1)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax1.set_xlim(0.5, 2.7)
ax1.set_ylim(-2.3, 0.1)
plt.legend()

ax2 = plt.subplot(212)
cat_brick_south_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='South', ax=ax2)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax2.set_xlim(0.5, 2.7)
ax2.set_ylim(-2.3, 0.1)
plt.legend()

plt.tight_layout()

# %%
fig = plt.figure(figsize=(8, 12))

ax4 = plt.subplot(511)
cat_brick_head_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Head', ax=ax4)

ax1 = plt.subplot(512)
cat_brick_north_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='North', ax=ax1)

ax5 = plt.subplot(513)
cat_brick_middle_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='brown', s=1, label='Middle', ax=ax5)

ax2 = plt.subplot(514)
cat_brick_south_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='South', ax=ax2)

ax3 = plt.subplot(515)
cat_brick_sfluff_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='South Fluff', ax=ax3)

axes = [ax1, ax2, ax3, ax4, ax5]
for a in axes:
    a.set_xlabel('F182M - F212N', fontsize=12)
    a.set_ylabel('F405N - F466N', fontsize=12)
    a.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    a.set_xlim(0.5, 2.7)
    a.set_ylim(-2.3, 0.1)
    a.legend()
    a.axvline(0.6)


plt.tight_layout()

# %%
# initialize a linear fitter
fit = fitting.LinearLSQFitter()

small_lim = 0.5

mask = cat_brick_north_rc.color('f182m', 'f212n') > small_lim
x = cat_brick_north_rc.color('f182m', 'f212n')[mask]
y = cat_brick_north_rc.color('f405n', 'f466n')[mask]

# initialize a linear model
line_init = models.Linear1D()

# fit the data with the fitter
fitted_line_1 = fit(line_init, x, y)

# plot
ax = plt.subplot(211)
ax.scatter(x, y, label='North', color='red', s=1, alpha=0.5)
ax.plot(x, fitted_line_1(x), 'k-', label=f'y = {fitted_line_1.slope.value:.2f}x + {fitted_line_1.intercept.value:.2f}')
ax.set(xlabel='[F182M] - [F212N]', ylabel='[F405N] - [F466N]')
ax.legend()
ax.set_xlim(small_lim, 3)
ax.set_ylim(-3, 1)

fit = fitting.LinearLSQFitter()
mask = cat_brick_south_rc.color('f182m', 'f212n') > small_lim
x = cat_brick_south_rc.color('f182m', 'f212n')[mask]
y = cat_brick_south_rc.color('f405n', 'f466n')[mask]
line_init = models.Linear1D()

ax = plt.subplot(212)
ax.scatter(x, y, label='South', color='blue', s=1, alpha=0.5)
fitted_line_2 = fit(line_init, x, y)
ax.plot(x, fitted_line_2(x), 'k-', label=f'y = {fitted_line_2.slope.value:.2f}x + {fitted_line_2.intercept.value:.2f}')
ax.set(xlabel='[F182M] - [F212N]', ylabel='[F405N] - [F466N]')
ax.legend()
ax.set_xlim(small_lim, 3)
ax.set_ylim(-3, 1)

plt.tight_layout()

# %%
# initialize a linear fitter
fit = fitting.LinearLSQFitter()

small_lim = 0.55

mask = cat_brick_north.color('f182m', 'f212n') > small_lim
x = cat_brick_north.color('f182m', 'f212n')[mask]
y = cat_brick_north.color('f405n', 'f466n')[mask]

# initialize a linear model
line_init = models.Linear1D()

# fit the data with the fitter
fitted_line_1 = fit(line_init, x, y)

# plot
ax = plt.subplot(211)
ax.scatter(x, y, label='North', color='red', s=1, alpha=0.1)
ax.plot(x, fitted_line_1(x), 'k-', label=f'y = {fitted_line_1.slope.value:.2f}x + {fitted_line_1.intercept.value:.2f}')
ax.set(xlabel='[F182M] - [F212N]', ylabel='[F405N] - [F466N]')
ax.legend()
ax.set_xlim(small_lim, 3)
ax.set_ylim(-3, 1)

fit = fitting.LinearLSQFitter()
mask = cat_brick_south.color('f182m', 'f212n') > small_lim
x = cat_brick_south.color('f182m', 'f212n')[mask]
y = cat_brick_south.color('f405n', 'f466n')[mask]
line_init = models.Linear1D()

ax = plt.subplot(212)
ax.scatter(x, y, label='South', color='blue', s=1, alpha=0.1)
fitted_line_2 = fit(line_init, x, y)
ax.plot(x, fitted_line_2(x), 'k-', label=f'y = {fitted_line_2.slope.value:.2f}x + {fitted_line_2.intercept.value:.2f}')
ax.set(xlabel='[F182M] - [F212N]', ylabel='[F405N] - [F466N]')
ax.legend()
ax.set_xlim(small_lim, 3)
ax.set_ylim(-3, 1)

plt.tight_layout()

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_head_rc.plot_position(ax=ax, color='green', s=1, label='Head', transform=ax.get_transform('world'))
cat_brick_sfluff_rc.plot_position(ax=ax, color='cyan', s=1, label='South Fluff', transform=ax.get_transform('world'))
cat_brick_nfluff_rc.plot_position(ax=ax, color='magenta', s=1, label='North Fluff', transform=ax.get_transform('world'))
cat_brick_punch_rc.plot_position(ax=ax, color='orange', s=1, label='Punch', transform=ax.get_transform('world'))
cat_brick_sfore_rc.plot_position(ax=ax, color='pink', s=1, label='South Foreground', transform=ax.get_transform('world'))
cat_brick_nclear_rc.plot_position(ax=ax, color='k', s=1, label='North Clear', transform=ax.get_transform('world'))

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
ax1 = plt.subplot(231)
cat_brick_head_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Head', ax=ax1)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax1.set_xlim(0.5, 2.7)
ax1.set_ylim(-2.3, 0.1)
plt.legend()

ax2 = plt.subplot(232)
cat_brick_sfluff_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='South Fluff', ax=ax2)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax2.set_xlim(0.5, 2.7)
ax2.set_ylim(-2.3, 0.1)
plt.legend()

ax3 = plt.subplot(233)
cat_brick_nfluff_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='magenta', s=1, label='North Fluff', ax=ax3)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax3.set_xlim(0.5, 2.7)
ax3.set_ylim(-2.3, 0.1)
plt.legend()

ax4 = plt.subplot(234)
cat_brick_punch_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Punch', ax=ax4)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax4.set_xlim(0.5, 2.7)
ax4.set_ylim(-2.3, 0.1)
plt.legend()

ax5 = plt.subplot(235)
cat_brick_sfore_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='pink', s=1, label='South Foreground', ax=ax5)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax5.set_xlim(0.5, 2.7)
ax5.set_ylim(-2.3, 0.1)
plt.legend()

ax6 = plt.subplot(236)
cat_brick_nclear_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='k', s=1, label='North Clear', ax=ax6)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax6.set_xlim(0.5, 2.7)
ax6.set_ylim(-2.3, 0.1)
plt.legend()

plt.tight_layout()

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_sfr_rc.plot_position(ax=ax, color='purple', s=1, label='Star Forming Region', transform=ax.get_transform('world'))

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
ax = plt.subplot(111)
cat_brick_sfr_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='purple', s=1, label='Star Forming Region', ax=ax)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
#ax.set_xlim(0.5, 2.7)
ax.set_ylim(-1.7, 0.5)
plt.legend()

plt.tight_layout()

# %%
ax = plt.subplot(111)
cat_brick.plot_CMD('f182m', 'f212n', 'f182m', color='gray', s=1, label='All Regions', ax=ax, alpha=0.1)
cat_brick_sfr.plot_CMD('f182m', 'f212n', 'f182m', color='purple', s=5, label='Star Forming Region', ax=ax)
cat_brick_sfr_rc.plot_CMD('f182m', 'f212n', 'f182m', color='red', s=5, label='Star Forming Region RC', ax=ax)
#plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax.set_xlim(0, 2.7)
#ax.set_ylim(-1.7, 0.5)
plt.legend()
#plt.gca().invert_yaxis()

ax.set_xlim(0, 2.7)
ax.set_ylim(22, 14)

plt.tight_layout()

# %%
ax = plt.subplot(111)
cat_f.plot_CMD('f182m', 'f212n', 'f182m', color='gray', s=1, label='All Regions', ax=ax, alpha=0.1)
cat_brick_sfr.plot_CMD('f182m', 'f212n', 'f182m', color='purple', s=5, label='Star Forming Region', ax=ax)
cat_brick_sfr_rc.plot_CMD('f182m', 'f212n', 'f182m', color='red', s=5, label='Star Forming Region RC', ax=ax)
#plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax.set_xlim(0, 2.7)
#ax.set_ylim(-1.7, 0.5)
plt.legend()
#plt.gca().invert_yaxis()

ax.set_xlim(0, 2.7)
ax.set_ylim(22, 14)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 ax = plt.subplot(111)
# ----> 2 cat_f.plot_CMD('f182m', 'f212n', 'f182m', color='gray', s=1, label='All Regions', ax=ax, alpha=0.1)
#       3 cat_brick_sfr.plot_CMD('f182m', 'f212n', 'f182m', color='purple', s=5, label='Star Forming Region', ax=ax)
#       4 cat_brick_sfr_rc.plot_CMD('f182m', 'f212n', 'f182m', color='red', s=5, label='Star Forming Region RC', ax=ax)
#
# NameError: name 'cat_f' is not defined

# %%
#ax = plt.subplot(221)
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
cat_list = [cat_brick_A, cat_brick_B, cat_brick_C, cat_brick_D]
labels = ['A', 'B', 'C', 'D']

for i in range(4):
    ax = axes.flatten()[i]
    cat = cat_list[i]
    cat.plot_CMD('f182m', 'f212n', 'f182m', color='gray', s=1, label=f'Brick {labels[i]}', ax=ax, alpha=0.1)
    cat_brick_sfr.plot_CMD('f182m', 'f212n', 'f182m', color='purple', s=5, label='Star Forming Region', ax=ax)
    cat_brick_sfr_rc.plot_CMD('f182m', 'f212n', 'f182m', color='red', s=5, label='Star Forming Region RC', ax=ax)
    ax.set_xlim(0, 2.7)
    ax.set_ylim(22, 14)
    ax.legend(loc='upper right')

plt.tight_layout()

# %% [markdown]
# # Full Catalog

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_north.plot_position(ax=ax, color='red', s=1, label='North', transform=ax.get_transform('world'), alpha=0.1)
cat_brick_south.plot_position(ax=ax, color='blue', s=1, label='South', transform=ax.get_transform('world'), alpha=0.1)
cat_brick_head.plot_position(ax=ax, color='green', s=1, label='Head', transform=ax.get_transform('world'), alpha=0.1)
cat_brick_sfluff.plot_position(ax=ax, color='cyan', s=1, label='South Fluff', transform=ax.get_transform('world'), alpha=0.1)
cat_brick_nfluff.plot_position(ax=ax, color='magenta', s=1, label='North Fluff', transform=ax.get_transform('world'), alpha=0.1)
cat_brick_punch.plot_position(ax=ax, color='orange', s=1, label='Punch', transform=ax.get_transform('world'), alpha=0.1)
cat_brick_sfore.plot_position(ax=ax, color='pink', s=1, label='South Foreground', transform=ax.get_transform('world'), alpha=0.1)
cat_brick_nclear.plot_position(ax=ax, color='k', s=1, label='North Clear', transform=ax.get_transform('world'), alpha=0.1)
cat_brick_sfrwide.plot_position(ax=ax, color='brown', s=1, label='Star Forming Region Wide', transform=ax.get_transform('world'), alpha=0.1)
cat_brick_sfr.plot_position(ax=ax, color='purple', s=1, label='Star Forming Region', transform=ax.get_transform('world'), alpha=0.1)
cat_brick_topc.plot_position(ax=ax, color='gray', s=1, label='Top Center', transform=ax.get_transform('world'), alpha=0.1)

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
print('stop hanging')

# %%
fig = plt.figure(figsize=(12, 10))

ax1 = plt.subplot(341)
cat_brick_north.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='North', ax=ax1, alpha=0.1)

ax2 = plt.subplot(342)
cat_brick_south.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='South', ax=ax2, alpha=0.1)

ax3 = plt.subplot(343)
cat_brick_head.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Head', ax=ax3, alpha=0.1)

ax4 = plt.subplot(344)
cat_brick_sfluff.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='South Fluff', ax=ax4, alpha=0.1)

ax5 = plt.subplot(345)
cat_brick_nfluff.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='magenta', s=1, label='North Fluff', ax=ax5, alpha=0.1)

ax6 = plt.subplot(346)
cat_brick_punch.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Punch', ax=ax6, alpha=0.1)

ax7 = plt.subplot(347)
cat_brick_sfore.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='pink', s=1, label='South Foreground', ax=ax7, alpha=0.2)

ax8 = plt.subplot(348)
cat_brick_nclear.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='k', s=1, label='North Clear', ax=ax8, alpha=0.1)

ax9 = plt.subplot(349)
cat_brick_sfr.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='purple', s=1, label='Star Forming Region', ax=ax9, alpha=0.2)

ax10 = plt.subplot(3,4,10)
cat_brick_sfrwide.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='brown', s=1, label='Star Forming Region Wide', ax=ax10, alpha=0.2)

ax11 = plt.subplot(3,4,11)
cat_brick_topc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='gray', s=1, label='Top Center', ax=ax11, alpha=0.1)

axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11]#, ax12]
for ax in axes:
    plt.sca(ax)
    plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    ax.set_xlim(0., 3.5)
    ax.set_ylim(-3, 0.3)
    plt.legend()

plt.tight_layout()

# %%
catalog_list = [cat_brick_north, cat_brick_south, cat_brick_head, cat_brick_sfluff, cat_brick_nfluff, cat_brick_punch, cat_brick_sfore, cat_brick_nclear, cat_brick_sfr, cat_brick_sfrwide, cat_brick_topc]
name_list = ['North', 'South', 'Head', 'South Fluff', 'North Fluff', 'Punch', 'South Foreground', 'North Clear', 'Star Forming Region', 'Star Forming Region Wide', 'Top Center']
color_list = ['k', 'r', 'g', 'b', 'orange', 'magenta', 'grey', 'cyan', 'purple', 'brown', 'gray']
cutoffs = [0.8, 0.9, 0.75, 0.9, 0.7, 0.75, 1, 0.8, 1, 1, 0.7]
rang = np.linspace(0.5, 2.7, 100)

fig = plt.figure(figsize=(12,10))
ax1 = plt.subplot(341)
ax2 = plt.subplot(342)
ax3 = plt.subplot(343)
ax4 = plt.subplot(344)
ax5 = plt.subplot(345)
ax6 = plt.subplot(346)
ax7 = plt.subplot(347)
ax8 = plt.subplot(348)
ax9 = plt.subplot(349)
ax10 = plt.subplot(3,4,10)
ax11 = plt.subplot(3,4,11)
axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11]

for i in range(len(catalog_list)):
    ax = axes[i]
    cat = catalog_list[i]
    cat = JWSTCatalog(cat.catalog[cat.color('f182m', 'f212n') > cutoffs[i]])
    cat.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', ax=ax, s=1, alpha=0.5, label=name_list[i], color=color_list[i])
    #ax.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    x = cat.color('f182m', 'f212n')
    y = cat.color('f405n', 'f466n')
    slopes = []
    intercepts = []

    for j in range(1000):
        indices = np.random.choice(len(x), len(x), replace=True)
        x_boot = x[indices]
        y_boot = y[indices]
        
        fit = fitting.LinearLSQFitter()
        line_boot = fit(models.Linear1D(), x_boot, y_boot)
        slopes.append(line_boot.slope.value)
        intercepts.append(line_boot.intercept.value)
        ax.plot(rang, line_boot(rang), color='gray', alpha=0.01)

    ax.plot(rang, np.mean(slopes) * rang + np.mean(intercepts), color='r', label=f'y = ({np.mean(slopes):.2f}$\pm${np.std(slopes):.2f})x + ({np.median(intercepts):.2f}$\pm${np.std(intercepts):.2f})', linewidth=2, linestyle='--')
    ax.set_xlim(0.5, 2.7)
    ax.set_ylim(-2.3, 0.5)
    ax.legend(loc='upper right')
    #ax.axvline(0.8)

plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 10))

ax1 = plt.subplot(341)
cat_brick_north.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='North', ax=ax1, alpha=0.3)

ax2 = plt.subplot(342)
cat_brick_south.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='South', ax=ax2, alpha=0.3)

ax3 = plt.subplot(343)
cat_brick_head.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Head', ax=ax3, alpha=0.3)

ax4 = plt.subplot(344)
cat_brick_sfluff.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='South Fluff', ax=ax4, alpha=0.3)

ax5 = plt.subplot(345)
cat_brick_nfluff.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='magenta', s=1, label='North Fluff', ax=ax5, alpha=0.3)

ax6 = plt.subplot(346)
cat_brick_punch.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Punch', ax=ax6, alpha=0.3)

ax7 = plt.subplot(347)
cat_brick_sfore.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='pink', s=1, label='South Foreground', ax=ax7, alpha=0.3)

ax8 = plt.subplot(348)
cat_brick_nclear.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='k', s=1, label='North Clear', ax=ax8, alpha=0.1)

ax9 = plt.subplot(349)
cat_brick_sfr.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='purple', s=1, label='Star Forming Region', ax=ax9, alpha=0.3)

ax10 = plt.subplot(3,4,10)
cat_brick_sfrwide.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='brown', s=1, label='Star Forming Region Wide', ax=ax10, alpha=0.3)

ax11 = plt.subplot(3,4,11)
cat_brick_topc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='gray', s=1, label='Top Center', ax=ax11, alpha=0.3)

axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11]#, ax12]
for ax in axes:
    plt.sca(ax)
    plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    ax.set_xlim(0.5, 1)
    ax.set_ylim(-1, 0.1)
    plt.legend()

plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
cat_claws = [cat_brick_claw1, cat_brick_claw2, cat_brick_claw3]
claw_labels = ['Claw 1', 'Claw 2', 'Claw 3']
color_claws = ['red', 'blue', 'green']

for i in range(3):
    ax = axes[i]
    cat = cat_claws[i]
    cat.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color=color_claws[i], s=1, label=claw_labels[i], ax=ax)
    ax.plot([0.5, 1.], [-0, -0.5], color='k', linestyle='dashed')
    ax.set_xlim(0, 3)
    ax.set_ylim(-1.5, 0.5)
    ax.legend()

plt.tight_layout()

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_north.plot_position(ax=ax, color='red', s=1, label='North', transform=ax.get_transform('world'))
cat_brick_south.plot_position(ax=ax, color='blue', s=1, label='South', transform=ax.get_transform('world'))

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
ax1 = plt.subplot(211)
cat_brick_north.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='North', ax=ax1)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax1.set_xlim(0.5, 2.7)
ax1.set_ylim(-2.3, 0.1)
plt.legend()

ax2 = plt.subplot(212)
cat_brick_south.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='South', ax=ax2)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax2.set_xlim(0.5, 2.7)
ax2.set_ylim(-2.3, 0.1)
plt.legend()

plt.tight_layout()

# %%
ax1 = plt.subplot(211)
cat_brick_north.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='North', ax=ax1, alpha=0.1)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax1.set_xlim(0., 2.7)
ax1.set_ylim(-2.3, 0.1)
ax1.axvline(0.1)
ax1.axvline(0.25)
ax1.axvline(0.5)
ax1.axvline(0.6)
plt.legend()

ax2 = plt.subplot(212)
cat_brick_south.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='South', ax=ax2, alpha=0.1)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax2.set_xlim(0., 2.7)
ax2.set_ylim(-2.3, 0.1)
ax2.axvline(0.1)
ax2.axvline(0.25)
ax2.axvline(0.5)
ax2.axvline(0.6)
plt.legend()

plt.tight_layout()

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_head.plot_position(ax=ax, color='green', s=1, label='Head', transform=ax.get_transform('world'))
cat_brick_sfluff.plot_position(ax=ax, color='cyan', s=1, label='South Fluff', transform=ax.get_transform('world'))
cat_brick_nfluff.plot_position(ax=ax, color='magenta', s=1, label='North Fluff', transform=ax.get_transform('world'))
cat_brick_punch.plot_position(ax=ax, color='orange', s=1, label='Punch', transform=ax.get_transform('world'))
cat_brick_sfore.plot_position(ax=ax, color='pink', s=1, label='South Foreground', transform=ax.get_transform('world'))
cat_brick_nclear.plot_position(ax=ax, color='k', s=1, label='North Clear', transform=ax.get_transform('world'))

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
ax1 = plt.subplot(231)
cat_brick_head.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Head', ax=ax1)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax1.set_xlim(0.5, 2.7)
ax1.set_ylim(-2.3, 0.1)
plt.legend()

ax2 = plt.subplot(232)
cat_brick_sfluff.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='South Fluff', ax=ax2)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax2.set_xlim(0.5, 2.7)
ax2.set_ylim(-2.3, 0.1)
plt.legend()

ax3 = plt.subplot(233)
cat_brick_nfluff.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='magenta', s=1, label='North Fluff', ax=ax3)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax3.set_xlim(0.5, 2.7)
ax3.set_ylim(-2.3, 0.1)
plt.legend()

ax4 = plt.subplot(234)
cat_brick_punch.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Punch', ax=ax4)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax4.set_xlim(0.5, 2.7)
ax4.set_ylim(-2.3, 0.1)
plt.legend()

ax5 = plt.subplot(235)
cat_brick_sfore.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='pink', s=1, label='South Foreground', ax=ax5)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax5.set_xlim(0.5, 2.7)
ax5.set_ylim(-2.3, 0.1)
plt.legend()

ax6 = plt.subplot(236)
cat_brick_nclear.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='k', s=1, label='North Clear', ax=ax6)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
ax6.set_xlim(0.5, 2.7)
ax6.set_ylim(-2.3, 0.1)
plt.legend()

plt.tight_layout()

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_sfr.plot_position(ax=ax, color='purple', s=1, label='Star Forming Region', transform=ax.get_transform('world'))

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
fig = plt.figure(figsize=(12,4))

ax = plt.subplot(131)
cat_brick_sfr.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='purple', s=1, label='Star Forming Region', ax=ax)
plt.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
#ax.set_xlim(0.5, 2.7)
ax.set_ylim(-1.7, 0.5)
plt.legend()

ax2 = plt.subplot(132)
cat_brick_sfr.plot_CMD('f182m', 'f212n', 'f182m', color='purple', s=1, label='Star Forming Region', ax=ax2)

ax3 = plt.subplot(133)
cat_brick_sfr.plot_CCD('f410m', 'f405n', 'f405n', 'f466n', color='purple', s=1, label='Star Forming Region', ax=ax3)
ax3.set_ylim(-1.7, 0.5)

plt.tight_layout()

# %% [markdown]
# # Numbered Regions

# %%
reg_brick_1 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_1.reg')
reg_brick_2 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_2.reg')
reg_brick_3 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_3.reg')
reg_brick_4 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_4.reg')
reg_brick_5 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_5.reg')
reg_brick_6 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_6.reg')
reg_brick_7 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_7.reg')
reg_brick_8 = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_8.reg')

reg_brick_left = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_left.reg')
reg_brick_right = Regions.read('/orange/adamginsburg/jwst/cloudc/regions_/brick_right.reg')

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

reg_brick_1[0].to_pixel(ww_brick).plot(ax=ax, color='red', label='Brick 1')
reg_brick_2[0].to_pixel(ww_brick).plot(ax=ax, color='blue', label='Brick 2')
reg_brick_3[0].to_pixel(ww_brick).plot(ax=ax, color='green', label='Brick 3')
reg_brick_4[0].to_pixel(ww_brick).plot(ax=ax, color='cyan', label='Brick 4')
reg_brick_5[0].to_pixel(ww_brick).plot(ax=ax, color='magenta', label='Brick 5')
reg_brick_6[0].to_pixel(ww_brick).plot(ax=ax, color='orange', label='Brick 6')
reg_brick_7[0].to_pixel(ww_brick).plot(ax=ax, color='pink', label='Brick 7')
reg_brick_8[0].to_pixel(ww_brick).plot(ax=ax, color='k', label='Brick 8')

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
cat_brick_1 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_1, ww_brick)) 
cat_brick_2 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_2, ww_brick)) 
cat_brick_3 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_3, ww_brick)) 
cat_brick_4 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_4, ww_brick)) 
cat_brick_5 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_5, ww_brick)) 
cat_brick_6 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_6, ww_brick)) 
cat_brick_7 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_7, ww_brick)) 
cat_brick_8 = JWSTCatalog(cat_brick.table_region_mask(reg_brick_8, ww_brick))

cat_brick_left = JWSTCatalog(cat_brick.table_region_mask(reg_brick_left, ww_brick)) 
cat_brick_right = JWSTCatalog(cat_brick.table_region_mask(reg_brick_right, ww_brick))

# %%
cat_brick.plot_CCD('f182m', 'f212n', 'f182m', 'f200w', s=1, alpha=0.1, color='k')
plt.xlim(0, 3)
plt.ylim(0, 1)

# %%
import itertools

cat_brick_left_fore = JWSTCatalog(cat_brick_left.catalog[cat_brick_left.color('f182m', 'f212n') < 0.35])
cat_brick_right_fore = JWSTCatalog(cat_brick_right.catalog[cat_brick_right.color('f182m', 'f212n') < 0.35])

print(np.round(np.nanmean(cat_brick_left_fore.color('f182m', 'f212n')), 2), r'$\pm$',  np.round(np.nanstd(cat_brick_left_fore.color('f182m', 'f212n')), 2))
print(np.round(np.nanmean(cat_brick_right_fore.color('f182m', 'f212n')), 2), r'$\pm$', np.round(np.nanstd(cat_brick_right_fore.color('f182m', 'f212n')), 2))

print('\n\n\n')

combos = list(itertools.combinations(['F182M', 'F212N', 'F405N', 'F187N', 'F466N', 'F410M', 'F115W', 'F200W', 'F356W', 'F444W'], 2)) # 115, 200, 356, 444
for c in combos: 
    color1 = cat_brick_left_fore.color(c[0].lower(), c[1].lower())
    color2 = cat_brick_right_fore.color(c[0].lower(), c[1].lower())
    print(f'{c[0]} - {c[1]}:')
    print('Left: ', np.round(np.nanmean(color1), 2), r'$\pm$', np.round(np.nanstd(color1), 2))
    print('Right:', np.round(np.nanmean(color2), 2), r'$\pm$', np.round(np.nanstd(color2), 2))
    print(f'{(np.nanmean(color1) - np.nanmean(color2))/np.sqrt(np.nanstd(color1)**2 + np.nanstd(color2)**2):0.2g}')
    print('\n')

# %%
cat_brick_1_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_1, ww_brick))
cat_brick_2_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_2, ww_brick)) 
cat_brick_3_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_3, ww_brick)) 
cat_brick_4_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_4, ww_brick)) 
cat_brick_5_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_5, ww_brick)) 
cat_brick_6_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_6, ww_brick)) 
cat_brick_7_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_7, ww_brick)) 
cat_brick_8_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_8, ww_brick))

cat_brick_left_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_left, ww_brick)) 
cat_brick_right_rc = JWSTCatalog(cat_brick_rc.table_region_mask(reg_brick_right, ww_brick))

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_1_rc.plot_position(ax=ax, color='red', s=1, label='Region 1', transform=ax.get_transform('world'))
cat_brick_2_rc.plot_position(ax=ax, color='blue', s=1, label='Region 2', transform=ax.get_transform('world'))
cat_brick_3_rc.plot_position(ax=ax, color='green', s=1, label='Region 3', transform=ax.get_transform('world'))
cat_brick_4_rc.plot_position(ax=ax, color='cyan', s=1, label='Region 4', transform=ax.get_transform('world'))
cat_brick_5_rc.plot_position(ax=ax, color='magenta', s=1, label='Region 5', transform=ax.get_transform('world'))
cat_brick_6_rc.plot_position(ax=ax, color='orange', s=1, label='Region 6', transform=ax.get_transform('world'))
cat_brick_7_rc.plot_position(ax=ax, color='pink', s=1, label='Region 7', transform=ax.get_transform('world'))
cat_brick_8_rc.plot_position(ax=ax, color='k', s=1, label='Region 8', transform=ax.get_transform('world'))

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
fig = plt.figure(figsize=(12, 6))

ax1 = plt.subplot(248)
cat_brick_1_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='Region 1', ax=ax1)

ax2 = plt.subplot(247)
cat_brick_2_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='Region 2', ax=ax2)

ax3 = plt.subplot(246)
cat_brick_3_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Region 3', ax=ax3)

ax4 = plt.subplot(245)
cat_brick_4_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='Region 4', ax=ax4)

ax5 = plt.subplot(244)
cat_brick_5_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='magenta', s=1, label='Region 5', ax=ax5)

ax6 = plt.subplot(243)
cat_brick_6_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Region 6', ax=ax6)

ax7 = plt.subplot(242)
cat_brick_7_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='pink', s=1, label='Region 7', ax=ax7)

ax8 = plt.subplot(241)
cat_brick_8_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='k', s=1, label='Region 8', ax=ax8)

axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]

for ax in axes:
    ax.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    ax.set_xlim(0.5, 2.7)
    ax.set_ylim(-2.3, 0.1)
    ax.legend()
    ax.axvline(0.6)

plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 6))
ax1 = plt.subplot(121)
cat_brick_left_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='Left Region', ax=ax1)

ax2 = plt.subplot(122)
cat_brick_right_rc.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='Right Region', ax=ax2)

axes = [ax1, ax2]
for ax in axes:
    ax.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    ax.set_xlim(0.5, 2.7)
    ax.set_ylim(-2.3, 0.1)
    ax.legend()
    ax.axvline(0.6)

plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 6))
ax1 = plt.subplot(121)
cat_brick_left.plot_CMD('f182m', 'f212n', 'f182m', color='pink', s=1, ax=ax1, alpha=0.5)
cat_brick_left_rc.plot_CMD('f182m', 'f212n', 'f182m', color='red', s=1, label='Left Region', ax=ax1)
plt.gca().invert_yaxis()

ax2 = plt.subplot(122)
cat_brick_right.plot_CMD('f182m', 'f212n', 'f182m', color='lightblue', s=1, ax=ax2, alpha=0.5)
cat_brick_right_rc.plot_CMD('f182m', 'f212n', 'f182m', color='blue', s=1, label='Right Region', ax=ax2)
plt.gca().invert_yaxis()

axes = [ax1, ax2]
for ax in axes:
    #ax.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    ax.set_xlim(0., 3)
    ax.set_ylim(22.5, 14.5)
    ax.legend()
    ax.axvline(0.8)
    ax.axvline(0.6)
    ax.axvline(0.4)
    ax.axvline(0.2)

plt.tight_layout()

# %%
ax = plt.subplot(projection=ww_brick)
plt.imshow(nanfield_brick)

cat_brick_1.plot_position(ax=ax, color='red', s=1, label='Region 1', transform=ax.get_transform('world'))
cat_brick_2.plot_position(ax=ax, color='blue', s=1, label='Region 2', transform=ax.get_transform('world'))
cat_brick_3.plot_position(ax=ax, color='green', s=1, label='Region 3', transform=ax.get_transform('world'))
cat_brick_4.plot_position(ax=ax, color='cyan', s=1, label='Region 4', transform=ax.get_transform('world'))
cat_brick_5.plot_position(ax=ax, color='magenta', s=1, label='Region 5', transform=ax.get_transform('world'))
cat_brick_6.plot_position(ax=ax, color='orange', s=1, label='Region 6', transform=ax.get_transform('world'))
cat_brick_7.plot_position(ax=ax, color='pink', s=1, label='Region 7', transform=ax.get_transform('world'))
cat_brick_8.plot_position(ax=ax, color='k', s=1, label='Region 8', transform=ax.get_transform('world'))

ax.set_xlabel('Declination')
ax.set_ylabel('Right Ascension')

# %%
fig = plt.figure(figsize=(12, 6))

ax1 = plt.subplot(248)
cat_brick_1.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='Region 1', ax=ax1)

ax2 = plt.subplot(247)
cat_brick_2.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='Region 2', ax=ax2)

ax3 = plt.subplot(246)
cat_brick_3.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Region 3', ax=ax3)

ax4 = plt.subplot(245)
cat_brick_4.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='Region 4', ax=ax4)

ax5 = plt.subplot(244)
cat_brick_5.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='magenta', s=1, label='Region 5', ax=ax5)

ax6 = plt.subplot(243)
cat_brick_6.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Region 6', ax=ax6)

ax7 = plt.subplot(242)
cat_brick_7.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='pink', s=1, label='Region 7', ax=ax7)

ax8 = plt.subplot(241)
cat_brick_8.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='k', s=1, label='Region 8', ax=ax8)

axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]

for ax in axes:
    ax.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    ax.set_xlim(0.5, 2.7)
    ax.set_ylim(-2.3, 0.1)
    ax.legend()
    ax.axvline(0.6)

plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 6))

ax1 = plt.subplot(241)
cat_brick_1.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='red', s=1, label='Region 1', ax=ax1)

ax2 = plt.subplot(242)
cat_brick_2.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='blue', s=1, label='Region 2', ax=ax2)

ax3 = plt.subplot(243)
cat_brick_3.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='green', s=1, label='Region 3', ax=ax3)

ax4 = plt.subplot(244)
cat_brick_4.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='cyan', s=1, label='Region 4', ax=ax4)

ax5 = plt.subplot(245)
cat_brick_5.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='magenta', s=1, label='Region 5', ax=ax5)

ax6 = plt.subplot(246)
cat_brick_6.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='orange', s=1, label='Region 6', ax=ax6)

ax7 = plt.subplot(247)
cat_brick_7.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='pink', s=1, label='Region 7', ax=ax7)

ax8 = plt.subplot(248)
cat_brick_8.plot_CCD('f182m', 'f212n', 'f405n', 'f466n', color='k', s=1, label='Region 8', ax=ax8)

axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]

for ax in axes:
    ax.plot([0.8, 1.75], [-0.6, -1.7], color='k', linestyle='dashed')
    ax.set_xlim(0., 2.7)
    ax.set_ylim(-2.3, 0.1)
    ax.legend()
    ax.axvline(0.6)
    ax.axvline(0.2)
    ax.axvline(0.35)

plt.tight_layout()

# %%
fig, axes = plt.subplots(2, 4, figsize=(12, 6))

catalogs_numbered = [cat_brick_1, cat_brick_2, cat_brick_3, cat_brick_4, cat_brick_5, cat_brick_6, cat_brick_7, cat_brick_8]
colors = ['red', 'blue', 'green', 'cyan', 'magenta', 'orange', 'pink', 'k']

for i in range(8):
    ax = axes.flatten()[i]
    cat = catalogs_numbered[i]
    ax.scatter(cat.catalog['Av'], cat.catalog['N(CO)'], color=colors[i], s=1, alpha=0.5, label=f'Region {i+1}')
    ax.set_xlabel('Av')
    ax.set_ylabel('N(CO)')
    ax.set_xlim(0, 80)
    ax.set_ylim(1e18, 5e19)
    ax.set_yscale('log')
    ax.legend()


plt.tight_layout()
